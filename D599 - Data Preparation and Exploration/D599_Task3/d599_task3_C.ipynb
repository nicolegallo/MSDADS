# %%
# Import libraries
import pandas as pd

# Load the dataset
df = pd.read_csv("Megastore_Dataset_Task_3_3.csv")  # Update the filename if needed

# Standardize column names
df.columns = df.columns.str.strip().str.replace(" ", "").str.replace("\u00a0", "")

# %%
# Encode ordinal variables
order_priority_map = {'Low': 1, 'Medium': 2, 'High': 3}
satisfaction_map = {
    'Prefer not to answer': 0,
    'Dissatisfied': 1,
    'Very dissatisfied': 2,
    'Satisfied': 3,
    'Very Satisfied': 4
}
df['OrderPriority'] = df['OrderPriority'].map(order_priority_map)
df['CustomerOrderSatisfaction'] = df['CustomerOrderSatisfaction'].map(satisfaction_map)

# Encode nominal variables with one-hot encoding
df_encoded = pd.get_dummies(df, columns=['Region', 'Segment'], prefix=['Region', 'Segment'])

# Save the encoded dataset
df_encoded.to_csv("d599_task3_encoded_dataset.csv", index=False)

# %%
# Transactional dataset prep & creation
# Filter for Corporate customers in the Northeast
filtered_df = df[(df['Segment'] == 'Corporate') & (df['Region'] == 'Northeast')]

# %%
# Group by OrderID and ProductName, then pivot into basket format
basket_df = (
    filtered_df
    .groupby(['OrderID', 'ProductName'])['Quantity']
    .sum().unstack().reset_index().fillna(0)
    .set_index('OrderID')
)

# %%
# Convert quantities to binary (1 = purchased, 0 = not purchased)
basket_encoded = basket_df.map(lambda x: 1 if x > 0 else 0)

# %%
# Save the transactional basket
basket_encoded.to_csv("d599_task3_transactional_dataset.csv")

# %%
# View a selected portion of the rows to prove dataset contains 0s and 1s
basket_encoded.iloc[10:20, 10:20]
# Out:
# ProductName  12 PENCILS SMALL TUBE SKULL  12 PENCILS TALL TUBE POSY  \
# OrderID
# 541981                                 0                          0
# 542433                                 0                          0
# 542629                                 0                          0
# 542735                                 0                          0
# 542922                                 0                          0
# 543030                                 0                          0
# 544069                                 0                          0
# 544115                                 1                          0
# 544200                                 0                          0
# 544585                                 0                          0
#
# ProductName  12 PENCILS TALL TUBE RED RETROSPOT  \
# OrderID
# 541981                                        0
# 542433                                        0
# 542629                                        0
# 542735                                        0
# 542922                                        0
# 543030                                        0
# 544069                                        1
# 544115                                        0
# 544200                                        0
# 544585                                        0
#
# ProductName  12 PENCILS TALL TUBE WOODLAND  \
# OrderID
# 541981                                   0
# 542433                                   0
# 542629                                   0
# 542735                                   0
# 542922                                   0
# 543030                                   0
# 544069                                   1
# 544115                                   0
# 544200                                   0
# 544585                                   0
#
# ProductName  16 PIECE CUTLERY SET PANTRY DESIGN  \
# OrderID
# 541981                                        0
# 542433                                        0
# 542629                                        0
# 542735                                        0
# 542922                                        0
# 543030                                        0
# 544069                                        0
# 544115                                        0
# 544200                                        0
# 544585                                        0
#
# ProductName  18PC WOODEN CUTLERY SET DISPOSABLE  20 DOLLY PEGS RETROSPOT  \
# OrderID
# 541981                                        0                        0
# 542433                                        0                        0
# 542629                                        0                        0
# 542735                                        0                        0
# 542922                                        0                        0
# 543030                                        0                        0
# 544069                                        0                        0
# 544115                                        0                        0
# 544200                                        0                        0
# 544585                                        0                        0
#
# ProductName  200 RED  WHITE BENDY STRAWS  3 HOOK HANGER MAGIC GARDEN  \
# OrderID
# 541981                                 0                           0
# 542433                                 0                           0
# 542629                                 0                           0
# 542735                                 0                           0
# 542922                                 0                           0
# 543030                                 0                           0
# 544069                                 0                           0
# 544115                                 0                           0
# 544200                                 0                           0
# 544585                                 0                           0
#
# ProductName  3 PIECE SPACEBOY COOKIE CUTTER SET
# OrderID
# 541981                                        0
# 542433                                        1
# 542629                                        0
# 542735                                        0
# 542922                                        0
# 543030                                        0
# 544069                                        0
# 544115                                        0
# 544200                                        0
# 544585                                        0

# %%
# Import libraries
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Load your transactional basket data
basket_encoded = pd.read_csv("d599_task3_transactional_dataset.csv", index_col=0)

# %%
# Changing type to bool, preferred by mlxtend

basket_encoded = basket_encoded.astype(bool)

# %%
# Check to see how many unique products, number of columns
print("Number of unique products:", basket_encoded.shape[1])
# Out:
# Number of unique products: 964

# %%
# Run Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(basket_encoded, min_support=0.05, use_colnames=True)

# %%
# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
# View the first few rules
print("✅ Apriori rules generated successfully!")
rules.head()
# Out:
# ✅ Apriori rules generated successfully!
#                      antecedents                    consequents  \
# 0  (ALARM CLOCK BAKELIKE ORANGE)   (ALARM CLOCK BAKELIKE GREEN)
# 1   (ALARM CLOCK BAKELIKE GREEN)  (ALARM CLOCK BAKELIKE ORANGE)
# 2    (ALARM CLOCK BAKELIKE PINK)   (ALARM CLOCK BAKELIKE GREEN)
# 3   (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE PINK)
# 4    (ALARM CLOCK BAKELIKE RED )   (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.050420            0.100840  0.050420    1.000000  9.916667
# 1            0.100840            0.050420  0.050420    0.500000  9.916667
# 2            0.084034            0.100840  0.067227    0.800000  7.933333
# 3            0.100840            0.084034  0.067227    0.666667  7.933333
# 4            0.084034            0.100840  0.075630    0.900000  8.925000
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.045336         inf       0.946903  0.500000   1.000000
# 1               1.0  0.045336    1.899160       1.000000  0.500000   0.473451
# 2               1.0  0.058753    4.495798       0.954128  0.571429   0.777570
# 3               1.0  0.058753    2.747899       0.971963  0.571429   0.636086
# 4               1.0  0.067156    8.991597       0.969419  0.692308   0.888785
#
#    kulczynski
# 0    0.750000
# 1    0.750000
# 2    0.733333
# 3    0.733333
# 4    0.825000

# %%
# Display relevant columns from the association rules table
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(10)
# Out:
#                              antecedents  \
# 0          (ALARM CLOCK BAKELIKE ORANGE)
# 1           (ALARM CLOCK BAKELIKE GREEN)
# 2            (ALARM CLOCK BAKELIKE PINK)
# 3           (ALARM CLOCK BAKELIKE GREEN)
# 4            (ALARM CLOCK BAKELIKE RED )
# 5           (ALARM CLOCK BAKELIKE GREEN)
# 6           (ALARM CLOCK BAKELIKE GREEN)
# 7  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 8            (ALARM CLOCK BAKELIKE RED )
# 9            (ALARM CLOCK BAKELIKE PINK)
#
#                              consequents   support  confidence      lift
# 0           (ALARM CLOCK BAKELIKE GREEN)  0.050420    1.000000  9.916667
# 1          (ALARM CLOCK BAKELIKE ORANGE)  0.050420    0.500000  9.916667
# 2           (ALARM CLOCK BAKELIKE GREEN)  0.067227    0.800000  7.933333
# 3            (ALARM CLOCK BAKELIKE PINK)  0.067227    0.666667  7.933333
# 4           (ALARM CLOCK BAKELIKE GREEN)  0.075630    0.900000  8.925000
# 5            (ALARM CLOCK BAKELIKE RED )  0.075630    0.750000  8.925000
# 6  (ROUND SNACK BOXES SET OF4 WOODLAND )  0.075630    0.750000  3.880435
# 7           (ALARM CLOCK BAKELIKE GREEN)  0.075630    0.391304  3.880435
# 8            (ALARM CLOCK BAKELIKE PINK)  0.067227    0.800000  9.520000
# 9            (ALARM CLOCK BAKELIKE RED )  0.067227    0.800000  9.520000
